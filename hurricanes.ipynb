# %%
# %pip install beautifulsoup4 requests
# %pip install "apache-airflow[celery]==3.0.0" --constraint "https://raw.githubusercontent.com/apache/airflow/constraints-3.0.0/constraints-3.10.txt"
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\georg\anaconda3\lib\site-packages (4.12.2)
# Requirement already satisfied: requests in c:\users\georg\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\georg\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\georg\anaconda3\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\georg\anaconda3\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\georg\anaconda3\lib\site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\georg\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: apache-airflow==3.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow[celery]==3.0.0) (3.0.0)
# Requirement already satisfied: apache-airflow-core==3.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.0.0)
# Requirement already satisfied: apache-airflow-task-sdk<1.1.0,>=1.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.0)
# Requirement already satisfied: apache-airflow-providers-celery>=3.8.3 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow[celery]==3.0.0) (3.10.6)
# Requirement already satisfied: a2wsgi>=1.10.8 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.10.8)
# Requirement already satisfied: aiosqlite>=0.20.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.21.0)
# Requirement already satisfied: alembic<2.0,>=1.13.1 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.15.2)
# Requirement already satisfied: apache-airflow-providers-common-compat>=1.6.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.6.0)
# Requirement already satisfied: apache-airflow-providers-common-io>=1.5.3 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.5.4)
# Requirement already satisfied: apache-airflow-providers-common-sql>=1.25.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.26.0)
# Requirement already satisfied: apache-airflow-providers-smtp>=2.0.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.0.3)
# Requirement already satisfied: apache-airflow-providers-standard>=0.4.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.0)
# Requirement already satisfied: argcomplete>=1.10 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.6.2)
# Requirement already satisfied: asgiref>=2.3.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.8.1)
# Requirement already satisfied: attrs!=25.2.0,>=22.1.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (25.3.0)
# Requirement already satisfied: cadwyn>=5.2.1 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (5.3.3)
# Requirement already satisfied: colorlog>=6.8.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (6.9.0)
# Requirement already satisfied: cron-descriptor>=1.2.24 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.4.5)
# Requirement already satisfied: croniter>=2.0.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (6.0.0)
# Requirement already satisfied: cryptography>=41.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (42.0.8)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.2.18)
# Requirement already satisfied: dill>=0.2.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.3.1.1)
# Requirement already satisfied: fastapi!=0.115.10,>=0.115.0 in c:\users\georg\anaconda3\lib\site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.115.12)
# Requirement already satisfied: flask>=2.1.1 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.2.5)
# Requirement already satisfied: gitpython>=3.1.40 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.1.44)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (23.0.0)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.27.0)
# Requirement already satisfied: importlib-metadata>=6.5 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (8.4.0)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.5 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.1.6)
# Requirement already satisfied: jsonschema>=4.19.1 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (4.23.0)
# Requirement already satisfied: lazy-object-proxy>=1.2.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.11.0)
# Requirement already satisfied: libcst>=1.1.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.7.0)
# Requirement already satisfied: linkify-it-py>=2.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.0.3)
# Requirement already satisfied: lockfile>=0.12.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.12.2)
# Requirement already satisfied: methodtools>=0.4.7 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.4.7)
# Requirement already satisfied: opentelemetry-api>=1.24.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp>=1.24.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: packaging>=23.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (24.2)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.12.1)
# Requirement already satisfied: pendulum<4.0,>=2.1.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.1.0)
# Requirement already satisfied: pluggy>=1.5.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.5.0)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (7.0.0)
# Requirement already satisfied: pydantic>=2.11.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.11.3)
# Requirement already satisfied: pygments!=2.19.0,>=2.0.1 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.19.1)
# Requirement already satisfied: pyjwt>=2.10.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.10.1)
# Requirement already satisfied: python-daemon>=3.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.9.0.post0)
# Requirement already satisfied: python-slugify>=5.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (8.0.4)
# Requirement already satisfied: requests<3,>=2.31.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.32.3)
# Requirement already satisfied: rich-argparse>=1.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.7.0)
# Requirement already satisfied: rich>=13.6.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (13.9.4)
# Requirement already satisfied: setproctitle>=1.3.3 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.3.5)
# Requirement already satisfied: sqlalchemy-jsonfield>=1.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.2)
# Requirement already satisfied: sqlalchemy-utils>=0.41.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.41.2)
# Requirement already satisfied: sqlalchemy<2.0,>=1.4.49 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.4.54)
# Requirement already satisfied: svcs>=25.1.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (25.1.0)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.9.0)
# Requirement already satisfied: tenacity!=8.2.0,>=8.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (9.1.2)
# Requirement already satisfied: termcolor>=3.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.0.1)
# Requirement already satisfied: universal-pathlib!=0.2.4,>=0.2.2 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.2.6)
# Requirement already satisfied: uuid6>=2024.7.10 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2024.7.10)
# Requirement already satisfied: celery<6,>=5.5.0 in c:\users\georg\anaconda3\lib\site-packages (from celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (5.5.1)
# Requirement already satisfied: flower>=1.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (2.0.1)
# Requirement already satisfied: aiologic>=0.14.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.14.0)
# Requirement already satisfied: fsspec>=2023.10.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2025.3.2)
# Requirement already satisfied: msgspec>=0.19.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.19.0)
# Requirement already satisfied: retryhttp!=1.3.0,>=1.2.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.3.2)
# Requirement already satisfied: structlog>=25.2.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (25.2.0)
# Requirement already satisfied: wrapt>=1.16.0 in c:\users\georg\anaconda3\lib\site-packages (from aiologic>=0.14.0->apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.17.2)
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\georg\anaconda3\lib\site-packages (from aiosqlite>=0.20.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (4.13.2)
# Requirement already satisfied: Mako in c:\users\georg\anaconda3\lib\site-packages (from alembic<2.0,>=1.13.1->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.3.10)
# Requirement already satisfied: sqlparse>=0.5.1 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql>=1.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.5.3)
# Requirement already satisfied: more-itertools>=9.0.0 in c:\users\georg\anaconda3\lib\site-packages (from apache-airflow-providers-common-sql>=1.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (10.7.0)
# Requirement already satisfied: starlette>=0.30.0 in c:\users\georg\anaconda3\lib\site-packages (from cadwyn>=5.2.1->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.46.2)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (4.2.1)
# Requirement already satisfied: kombu<5.6,>=5.5.2 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (5.5.3)
# Requirement already satisfied: vine<6.0,>=5.1.0 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (5.1.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (8.1.8)
# Requirement already satisfied: click-didyoumean>=0.3.0 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in c:\users\georg\anaconda3\lib\site-packages (from celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (1.1.1)
# Requirement already satisfied: redis!=4.5.5,<6.0.0,>=4.5.2 in c:\users\georg\anaconda3\lib\site-packages (from celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (5.2.1)
# Requirement already satisfied: colorama in c:\users\georg\anaconda3\lib\site-packages (from colorlog>=6.8.2->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.4.6)
# Requirement already satisfied: pytz>2021.1 in c:\users\georg\anaconda3\lib\site-packages (from croniter>=2.0.2->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2025.2)
# Requirement already satisfied: cffi>=1.12 in c:\users\georg\anaconda3\lib\site-packages (from cryptography>=41.0.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.17.1)
# Requirement already satisfied: fastapi-cli>=0.0.5 in c:\users\georg\anaconda3\lib\site-packages (from fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.0.7)
# Requirement already satisfied: python-multipart>=0.0.18 in c:\users\georg\anaconda3\lib\site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in c:\users\georg\anaconda3\lib\site-packages (from fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.2.0)
# Requirement already satisfied: uvicorn>=0.12.0 in c:\users\georg\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.34.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\georg\anaconda3\lib\site-packages (from flask>=2.1.1->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.2.3)
# Requirement already satisfied: tornado<7.0.0,>=5.0.0 in c:\users\georg\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (6.4.2)
# Requirement already satisfied: prometheus-client>=0.8.0 in c:\users\georg\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (0.21.1)
# Requirement already satisfied: humanize in c:\users\georg\anaconda3\lib\site-packages (from flower>=1.0.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\georg\anaconda3\lib\site-packages (from gitpython>=3.1.40->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (4.0.12)
# Requirement already satisfied: anyio in c:\users\georg\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (4.9.0)
# Requirement already satisfied: certifi in c:\users\georg\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\georg\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.8)
# Requirement already satisfied: idna in c:\users\georg\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.10)
# Requirement already satisfied: sniffio in c:\users\georg\anaconda3\lib\site-packages (from httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\georg\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\georg\anaconda3\lib\site-packages (from importlib-metadata>=6.5->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\georg\anaconda3\lib\site-packages (from jinja2>=3.1.5->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\georg\anaconda3\lib\site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\georg\anaconda3\lib\site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\georg\anaconda3\lib\site-packages (from jsonschema>=4.19.1->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.24.0)
# Requirement already satisfied: pyyaml>=5.2 in c:\users\georg\anaconda3\lib\site-packages (from libcst>=1.1.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (6.0.2)
# Requirement already satisfied: uc-micro-py in c:\users\georg\anaconda3\lib\site-packages (from linkify-it-py>=2.0.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.3)
# Requirement already satisfied: wirerope>=0.4.7 in c:\users\georg\anaconda3\lib\site-packages (from methodtools>=0.4.7->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.27.0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http==1.27.0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.65.5)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: opentelemetry-sdk~=1.27.0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.27.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-proto==1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (4.25.6)
# Requirement already satisfied: tzdata>=2020.1 in c:\users\georg\anaconda3\lib\site-packages (from pendulum<4.0,>=2.1.2->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\georg\anaconda3\lib\site-packages (from pydantic>=2.11.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\georg\anaconda3\lib\site-packages (from pydantic>=2.11.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\georg\anaconda3\lib\site-packages (from pydantic>=2.11.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\georg\anaconda3\lib\site-packages (from python-dateutil>=2.7.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\georg\anaconda3\lib\site-packages (from python-slugify>=5.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\georg\anaconda3\lib\site-packages (from requests<3,>=2.31.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\georg\anaconda3\lib\site-packages (from requests<3,>=2.31.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.4.0)
# Requirement already satisfied: types-requests in c:\users\georg\anaconda3\lib\site-packages (from retryhttp!=1.3.0,>=1.2.0->apache-airflow-task-sdk<1.1.0,>=1.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.32.0.20250328)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\georg\anaconda3\lib\site-packages (from rich>=13.6.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.0.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\georg\anaconda3\lib\site-packages (from sqlalchemy<2.0,>=1.4.49->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (3.2.1)
# Requirement already satisfied: pycparser in c:\users\georg\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=41.0.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.22)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in c:\users\georg\anaconda3\lib\site-packages (from click-repl>=0.2.0->celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (3.0.51)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\georg\anaconda3\lib\site-packages (from email-validator>=2.0.0->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (2.7.0)
# Requirement already satisfied: typer>=0.12.3 in c:\users\georg\anaconda3\lib\site-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.15.2)
# Requirement already satisfied: rich-toolkit>=0.11.1 in c:\users\georg\anaconda3\lib\site-packages (from fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.14.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\georg\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.40->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (5.0.2)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in c:\users\georg\anaconda3\lib\site-packages (from kombu<5.6,>=5.5.2->celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (5.3.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\georg\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.6.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.1.2)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\georg\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\georg\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\georg\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\georg\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (15.0.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\georg\anaconda3\lib\site-packages (from opentelemetry-sdk~=1.27.0->opentelemetry-exporter-otlp-proto-grpc==1.27.0->opentelemetry-exporter-otlp>=1.24.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (0.48b0)
# Requirement already satisfied: wcwidth in c:\users\georg\anaconda3\lib\site-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery<6,>=5.5.0->celery[redis]<6,>=5.5.0->apache-airflow-providers-celery>=3.8.3->apache-airflow[celery]==3.0.0) (0.2.13)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\georg\anaconda3\lib\site-packages (from typer>=0.12.3->fastapi-cli>=0.0.5->fastapi-cli[standard]>=0.0.5; extra == "standard"->fastapi[standard]!=0.115.10,>=0.115.0->apache-airflow-core==3.0.0->apache-airflow==3.0.0->apache-airflow[celery]==3.0.0) (1.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os
import re
from urllib.parse import urljoin
from PIL import Image
import glob

# %%
file_path = "data/hurdat2-1851-2024-040425.csv"

records = []
storm_id, storm_name = None, None

with open(file_path, "r") as f:
    for line in f:
        parts = [p.strip() for p in line.split(",")]
        if len(parts) == 4:
            storm_id, storm_name, count, nan = parts
            continue
        
        if len(parts) > 4:
            date, time, record_id, status, lat, lon, maxwind, minpressure, thirtyne, thirtyse, thirtysw, thirtynw, fivene, fivese, fivesw, fivenw, sixne, sixse, sixsw, sixnw, radmaxwind = parts
            records.append([
                storm_id, storm_name, date, time, record_id, status,
                lat, lon, maxwind, minpressure, thirtyne, thirtyse, thirtysw,
                thirtynw, fivene, fivese, fivesw, fivenw, sixne, sixse, sixsw,
                sixnw, radmaxwind
            ])

# Define column names
cols = ["SID", "Name", "Date", "Time", "RecordID", "Status", "Latitude", "Longitude",
        "MaxWind(kn)", "MinPressure", "34NE", "34SE", "34SW", "34NW", "50NE",
        "50SE", "50SW", "50NW", "64NE", "64SE", "64SW", "64NW", "RadiusOfMaxWind"]

df = pd.DataFrame(records, columns=cols)

df = df.replace(["", " ", "-999"], pd.NA)

df
# Out:
#             SID     Name      Date  Time RecordID Status Latitude Longitude  \
# 0      AL011851  UNNAMED  18510625  0000     <NA>     HU    28.0N     94.8W
# 1      AL011851  UNNAMED  18510625  0600     <NA>     HU    28.0N     95.4W
# 2      AL011851  UNNAMED  18510625  1200     <NA>     HU    28.0N     96.0W
# 3      AL011851  UNNAMED  18510625  1800     <NA>     HU    28.1N     96.5W
# 4      AL011851  UNNAMED  18510625  2100        L     HU    28.2N     96.8W
# ...         ...      ...       ...   ...      ...    ...      ...       ...
# 55225  AL192024     SARA  20241117  0600     <NA>     TS    16.5N     87.5W
# 55226  AL192024     SARA  20241117  1200     <NA>     TS    16.8N     87.9W
# 55227  AL192024     SARA  20241117  1400        L     TS    17.0N     88.3W
# 55228  AL192024     SARA  20241117  1800     <NA>     TD    17.4N     89.1W
# 55229  AL192024     SARA  20241118  0000     <NA>     TD    17.9N     90.2W
#
#       MaxWind(kn) MinPressure  ... 34NW 50NE 50SE 50SW 50NW 64NE 64SE 64SW  \
# 0              80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1              80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2              80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3              80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4              80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...           ...         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 55225          35        1001  ...   90    0    0    0    0    0    0    0
# 55226          35        1001  ...   60    0    0    0    0    0    0    0
# 55227          35        1001  ...   60    0    0    0    0    0    0    0
# 55228          30        1003  ...    0    0    0    0    0    0    0    0
# 55229          25        1004  ...    0    0    0    0    0    0    0    0
#
#       64NW RadiusOfMaxWind
# 0      NaN             NaN
# 1      NaN             NaN
# 2      NaN             NaN
# 3      NaN             NaN
# 4      NaN             NaN
# ...    ...             ...
# 55225    0              40
# 55226    0              40
# 55227    0              40
# 55228    0              50
# 55229    0              50
#
# [55230 rows x 23 columns]

# %%
# Convert date column to datetime.date (day resolution)
df["Date"] = pd.to_datetime(df["Date"], format="%Y%m%d").dt.date

# Convert time column to datetime.time (hour + minute only)
df["Time"] = pd.to_datetime(df["Time"].str.zfill(4), format="%H%M").dt.time

df
# Out:
#             SID     Name        Date      Time RecordID Status Latitude  \
# 0      AL011851  UNNAMED  1851-06-25  00:00:00     <NA>     HU    28.0N
# 1      AL011851  UNNAMED  1851-06-25  06:00:00     <NA>     HU    28.0N
# 2      AL011851  UNNAMED  1851-06-25  12:00:00     <NA>     HU    28.0N
# 3      AL011851  UNNAMED  1851-06-25  18:00:00     <NA>     HU    28.1N
# 4      AL011851  UNNAMED  1851-06-25  21:00:00        L     HU    28.2N
# ...         ...      ...         ...       ...      ...    ...      ...
# 55225  AL192024     SARA  2024-11-17  06:00:00     <NA>     TS    16.5N
# 55226  AL192024     SARA  2024-11-17  12:00:00     <NA>     TS    16.8N
# 55227  AL192024     SARA  2024-11-17  14:00:00        L     TS    17.0N
# 55228  AL192024     SARA  2024-11-17  18:00:00     <NA>     TD    17.4N
# 55229  AL192024     SARA  2024-11-18  00:00:00     <NA>     TD    17.9N
#
#       Longitude MaxWind(kn) MinPressure  ... 34NW 50NE 50SE 50SW 50NW 64NE  \
# 0         94.8W          80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 1         95.4W          80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 2         96.0W          80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 3         96.5W          80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN
# 4         96.8W          80        <NA>  ...  NaN  NaN  NaN  NaN  NaN  NaN
# ...         ...         ...         ...  ...  ...  ...  ...  ...  ...  ...
# 55225     87.5W          35        1001  ...   90    0    0    0    0    0
# 55226     87.9W          35        1001  ...   60    0    0    0    0    0
# 55227     88.3W          35        1001  ...   60    0    0    0    0    0
# 55228     89.1W          30        1003  ...    0    0    0    0    0    0
# 55229     90.2W          25        1004  ...    0    0    0    0    0    0
#
#       64SE 64SW 64NW RadiusOfMaxWind
# 0      NaN  NaN  NaN             NaN
# 1      NaN  NaN  NaN             NaN
# 2      NaN  NaN  NaN             NaN
# 3      NaN  NaN  NaN             NaN
# 4      NaN  NaN  NaN             NaN
# ...    ...  ...  ...             ...
# 55225    0    0    0              40
# 55226    0    0    0              40
# 55227    0    0    0              40
# 55228    0    0    0              50
# 55229    0    0    0              50
#
# [55230 rows x 23 columns]

# %%
url = "https://www.star.nesdis.noaa.gov/GOES/sector_band.php?sat=G19&sector=taw&band=10&length=12&dim=0"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

img_urls = [urljoin(url, img.get("src")) for img in soup.find_all("img") if img.get("src")]

# Filter for real satellite frame URLs (GOES imagery)
frame_urls = [u for u in img_urls if "GOES19" in u and u.endswith(".jpg")]

print(f"Found {len(frame_urls)} image frames")

os.makedirs("data/satellite_obs/frames", exist_ok=True)
for i, frame_url in enumerate(frame_urls):
    img_data = requests.get(frame_url).content
    with open(f"data/satellite_obs/frames/frame_{i:02d}.jpg", "wb") as f:
        f.write(img_data)
# Out:
# Found 12 image frames

# %%
frames = []
for file in sorted(glob.glob("data/satellite_obs/frames/frame_*.jpg")):
    frame = Image.open(file)
    frames.append(frame)

# Save as animated GIF
frames[0].save(
    "data/satellite_obs/satellite_animation.gif",
    save_all=True,
    append_images=frames[1:],
    duration=200,  # milliseconds per frame
    loop=0
)

print("GIF saved as satellite_animation.gif")
# Out:
# GIF saved as satellite_animation.gif
